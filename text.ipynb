# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
y = 10

# %%
y
# Out:
# 10

# %%
datos.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 datos.plot.bar()
#
# NameError: name 'datos' is not defined

# %%
import pandas as pd
datos = pd.DataFrame({"carros": [4,5], "motos":[5,2]}, index=["ajencia1","agencia2"])

# %%
datos
# Out:
#           carros  motos
# ajencia1       4      5
# agencia2       5      2

# %%
pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.9 kB 1.3 MB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 650.2 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 538.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 653.6 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 656.4 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 655.4 kB/s eta 0:00:18
#    ---------------------------------------- 0.1/11.5 MB 599.1 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/11.5 MB 607.9 kB/s eta 0:00:19
# ...

# %%
datos
# Out:
#           carros  motos
# ajencia1       4      5
# agencia2       5      2

# %%
datos.plot.bar()
# Out:
# <Axes: >

# %%
import pandas as pd
datos = pd.DataFrame({ "manzanas": [3, 2], "peras" : [1, 4]}, index=["Juan", "Pedro"])
datos
# Out:
#        manzanas  peras
# Juan          3      1
# Pedro         2      4

# %%
datos.plot.bar()
# Out:
# <Axes: >

# %%
l=-25

# %%
type(l)
# Out:
# int

# %%
print(27/7)
print(27//7)
print(27%7)
# Out:
# 3.857142857142857
# 3
# 6

# %%
a=5
b=7

# %%
if a < b:
    print('a es menor que b')
elif a > b:
    print('a mayor que b')
else:
    print('a y b son iguales')
# Out:
# a es menor que b

# %%
num = 5
if num>10:
    print("Soy mayor")
elif num<10:
    print("Soy menor")
else:
    print("Soy igual")
# Out:
# Soy menor

# %%
num = 5
if num>10:
    print("Soy mayor")
elif num<10:
    print("Soy menor que diez y como estoy primero me voy a ejecutar")
elif num<7:
    print("Soy también menor")
else:
    print("Soy igual")
# Out:
# Soy menor que diez y como estoy primero me voy a ejecutar
